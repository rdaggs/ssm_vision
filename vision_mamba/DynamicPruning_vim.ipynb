# %%
# Google Drive + working directory path
from google.colab import drive
drive.mount('/content/drive')

PATH = '/content/drive/MyDrive/Vision24/'
VERSION = 'dynamicPruning'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

print(os.path.isdir(PATH))
assert os.path.isdir(PATH)
# Out:
# True

# %%
CHECKPOINT_PATH = os.path.join(PATH, VERSION)
os.makedirs(CHECKPOINT_PATH, exist_ok=True)


print(os.path.isdir(CHECKPOINT_PATH))
assert os.path.isdir(CHECKPOINT_PATH)
# Out:
# True

# %%
# verify >16GB of RAM
# !nvidia-smi
# Out:
# Mon Nov 18 01:43:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0              66W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install torch
# !pip install zetascale
# !pip install swarms
# !pip install torchinfo

import torch
from einops import rearrange, repeat
from einops.layers.torch import Rearrange
from torch import nn, Tensor
from zeta.nn import SSM
from einops.layers.torch import Reduce

# %%
# For pruning
import math
import torch.nn.utils.prune as prune

def calculate_sparsity(epoch, start_epoch, end_epoch, initial_sparsity, final_sparsity):
    if epoch < start_epoch:
        return initial_sparsity
    if epoch > end_epoch:
        return final_sparsity
    progress = (epoch - start_epoch) / (end_epoch - start_epoch)
    return initial_sparsity + (final_sparsity - initial_sparsity) * (1 - math.cos(progress * math.pi)) / 2

def dynamic_pruning(model, epoch, start_epoch, end_epoch, initial_sparsity, final_sparsity):
    sparsity = calculate_sparsity(epoch, start_epoch, end_epoch, initial_sparsity, final_sparsity)
    for name, module in model.named_modules():
        if isinstance(module, nn.Conv1d) or isinstance(module, nn.Linear):
          # Remove any existing masks to avoid cumulative pruning
            if hasattr(module, "weight_mask"):
                prune.remove(module, "weight")

            # Reduce pruning for critical layers
            if "first_layer" in name or "output_head" in name:
                layer_sparsity = sparsity * 0.5  # Prune less in critical layers
            else:
                layer_sparsity = sparsity
            prune.l1_unstructured(module, name="weight", amount=layer_sparsity)
            print(f"Epoch {epoch}: Pruned {name} to {layer_sparsity * 100:.2f}% sparsity")


def check_sparsity(model, epoch):
    print(f"After epoch {epoch+1}:")
    for name, module in model.named_modules():
        if hasattr(module, 'weight') and module.weight is not None:
            sparsity = float(torch.sum(module.weight == 0)) / module.weight.nelement()
            print(f"\tSparsity in {name}: {sparsity:.2%}")

# %%
def pair(t):
    return t if isinstance(t, tuple) else (t, t)


def output_head(dim: int, num_classes: int):
    """
    Creates a head for the output layer of a model.

    Args:
        dim (int): The input dimension of the head.
        num_classes (int): The number of output classes.

    Returns:
        nn.Sequential: The output head module.
    """
    return nn.Sequential(
        Reduce("b s d -> b d", "mean"),
        nn.LayerNorm(dim),
        nn.Linear(dim, num_classes),
    )


class VisionEncoderMambaBlock(nn.Module):
    def __init__(
        self,
        dim: int,
        dt_rank: int,
        dim_inner: int,
        d_state: int,
    ):
        super().__init__()
        self.dim = dim
        self.dt_rank = dt_rank
        self.dim_inner = dim_inner
        self.d_state = d_state
        self.forward_conv1d = nn.Conv1d(in_channels=dim, out_channels=dim, kernel_size=1)
        self.backward_conv1d = nn.Conv1d(in_channels=dim, out_channels=dim, kernel_size=1)
        self.norm = nn.LayerNorm(dim)
        self.silu = nn.SiLU()
        self.ssm = SSM(dim, dt_rank, dim_inner, d_state)

        self.proj = nn.Linear(dim, dim) # projection layer
        self.softplus = nn.Softplus()


    def forward(self, x: torch.Tensor):
        b, s, d = x.shape

        skip = x            # skip connection
        x = self.norm(x)
        z = self.silu(self.proj(x))   # project --> activation for gating
        x = self.proj(x)

        x1 = self.process_direction(x, self.forward_conv1d, self.ssm,)
        x2 = self.process_direction(x, self.backward_conv1d, self.ssm,)

        x1 *= z
        x2 *= z

        # residual
        return x1 + x2 + skip

    def process_direction(
        self,
        x: Tensor,
        conv1d: nn.Conv1d,
        ssm: SSM,
    ):
        x = rearrange(x, "b s d -> b d s")
        x = self.softplus(conv1d(x))
        x = rearrange(x, "b d s -> b s d")
        x = ssm(x)
        return x


class Vim(nn.Module):
    def __init__(
        self,
        dim: int,
        dt_rank: int = 32,
        dim_inner: int = None,
        d_state: int = None,
        num_classes: int = None,
        image_size: int = 224,
        patch_size: int = 16,
        channels: int = 3,
        dropout: float = 0.1,
        depth: int = 12,
        *args,
        **kwargs,
    ):
        super().__init__()
        self.dim = dim
        self.dt_rank = dt_rank
        self.dim_inner = dim_inner
        self.d_state = d_state
        self.num_classes = num_classes
        self.image_size = image_size
        self.patch_size = patch_size
        self.channels = channels
        self.dropout = dropout
        self.depth = depth

        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)
        patch_dim = channels * patch_height * patch_width

        self.to_patch_embedding = nn.Sequential(
            Rearrange(
                "b c (h p1) (w p2) -> b (h w) (p1 p2 c)",
                p1=patch_height,
                p2=patch_height,
            ),
            nn.Linear(patch_dim, dim),
        )

        self.dropout = nn.Dropout(dropout)
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.to_latent = nn.Identity()
        self.layers = nn.ModuleList()        # encoder layers
        for _ in range(depth):
            self.layers.append(
                VisionEncoderMambaBlock(
                    dim=dim,
                    dt_rank=dt_rank,
                    dim_inner=dim_inner,
                    d_state=d_state,
                    *args,
                    **kwargs,
                )
            )
        self.output_head = output_head(dim, num_classes)

    def forward(self, x: Tensor):
        b, c, h, w = x.shape
        x = self.to_patch_embedding(x)
        b, n, _ = x.shape
        cls_tokens = repeat(self.cls_token, "() n d -> b n d", b=b)
        # x = torch.cat((cls_tokens, x), dim=1)
        x = self.dropout(x)
        for layer in self.layers:
            x = layer(x)

        x = self.to_latent(x)
        # x = reduce(x, "b s d -> b d", "mean")
        return self.output_head(x)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from einops import repeat

model = Vim(dim=96,
            dt_rank=16,
            dim_inner=96,
            d_state=96,
            num_classes=10,
            image_size=32,
            patch_size=4,
            channels=3,
            dropout=0.1,
            depth=10,)

batch_size = 256
epochs = 100

# Pruning config
start_epoch = 10 # Epoch at which pruning begins
end_epoch = 70 # Epoch at which pruning stops
initial_sparsity = 0.0 # No pruning initially)
final_sparsity = 0.6  # Target 60% sparsity

transform = transforms.Compose([
    # transforms.Resize([224,224]),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

training_data = torchvision.datasets.CIFAR10(root = './dataa',train=True,download=True,transform=transform)
testing_data = torchvision.datasets.CIFAR10(root = './data',train=False,download=True,transform=transform)

training_loader = DataLoader(training_data, batch_size=batch_size, shuffle=True, num_workers=4)
testing_loader = DataLoader(testing_data, batch_size=batch_size, shuffle=True, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print('epochs: ', epochs)
print('Training data: ', len(training_loader))
print('Total steps: ', epochs*len(training_loader))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# epochs:  100
# Training data:  196
# Total steps:  19600
# Device: cuda

# %%
import time
import pandas as pd
import numpy as np

_start = time.time()
print(_start)

__losses = []
__n = 100
# Out:
# 1731894223.0920682

# %%
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr = 0.003)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

for epoch in range(epochs):
    if epoch >= start_epoch and epoch <= end_epoch:
        # Apply dynamic pruning only during pruning phase
        dynamic_pruning(model, epoch, start_epoch, end_epoch, initial_sparsity, final_sparsity)

    model.train()
    running_loss = 0.0

    for i, (inputs,labels) in enumerate(training_loader):
        inputs,labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        # print(f'batch {i} completed')

        __losses.append(loss.item())
        running_loss += loss.item()

        if(i % __n == 0):
            print(f"Epoch [{epoch + 1}/{epochs}], Step [{i + 1}/{len(training_loader)}], Loss: {running_loss / __n:.4f}")
            running_loss = 0.0

    print(f"Epoch {epoch+1} finished. Saving checkpoint...")
    if epoch >= start_epoch and epoch <= end_epoch:
        check_sparsity(model, epoch)

    scheduler.step()
# Out:
# Streaming output truncated to the last 5000 lines.
# 	Sparsity in layers.4.ssm.dt_proj_layer: 13.67%
# 	Sparsity in layers.4.proj: 13.66%
# 	Sparsity in layers.5.forward_conv1d: 13.66%
# 	Sparsity in layers.5.backward_conv1d: 13.66%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 13.66%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 13.67%
# 	Sparsity in layers.5.proj: 13.66%
# 	Sparsity in layers.6.forward_conv1d: 13.66%
# 	Sparsity in layers.6.backward_conv1d: 13.66%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 13.66%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 13.67%
# 	Sparsity in layers.6.proj: 13.66%
# 	Sparsity in layers.7.forward_conv1d: 13.66%
# 	Sparsity in layers.7.backward_conv1d: 13.66%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 13.66%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 13.67%
# 	Sparsity in layers.7.proj: 13.66%
# 	Sparsity in layers.8.forward_conv1d: 13.66%
# 	Sparsity in layers.8.backward_conv1d: 13.66%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 13.66%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 13.67%
# 	Sparsity in layers.8.proj: 13.66%
# 	Sparsity in layers.9.forward_conv1d: 13.66%
# 	Sparsity in layers.9.backward_conv1d: 13.66%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 13.66%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 13.67%
# 	Sparsity in layers.9.proj: 13.66%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 6.88%
# Epoch 30: Pruned to_patch_embedding.1 to 15.00% sparsity
# Epoch 30: Pruned layers.0.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.0.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.0.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.0.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.0.proj to 15.00% sparsity
# Epoch 30: Pruned layers.1.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.1.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.1.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.1.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.1.proj to 15.00% sparsity
# Epoch 30: Pruned layers.2.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.2.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.2.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.2.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.2.proj to 15.00% sparsity
# Epoch 30: Pruned layers.3.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.3.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.3.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.3.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.3.proj to 15.00% sparsity
# Epoch 30: Pruned layers.4.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.4.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.4.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.4.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.4.proj to 15.00% sparsity
# Epoch 30: Pruned layers.5.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.5.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.5.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.5.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.5.proj to 15.00% sparsity
# Epoch 30: Pruned layers.6.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.6.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.6.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.6.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.6.proj to 15.00% sparsity
# Epoch 30: Pruned layers.7.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.7.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.7.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.7.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.7.proj to 15.00% sparsity
# Epoch 30: Pruned layers.8.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.8.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.8.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.8.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.8.proj to 15.00% sparsity
# Epoch 30: Pruned layers.9.forward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.9.backward_conv1d to 15.00% sparsity
# Epoch 30: Pruned layers.9.ssm.deltaBC_layer to 15.00% sparsity
# Epoch 30: Pruned layers.9.ssm.dt_proj_layer to 15.00% sparsity
# Epoch 30: Pruned layers.9.proj to 15.00% sparsity
# Epoch 30: Pruned output_head.2 to 7.50% sparsity
# Epoch [31/100], Step [1/196], Loss: 0.0037
# Epoch [31/100], Step [101/196], Loss: 0.4125
# Epoch 31 finished. Saving checkpoint...
# After epoch 31:
# 	Sparsity in to_patch_embedding.1: 15.00%
# 	Sparsity in layers.0.forward_conv1d: 15.00%
# 	Sparsity in layers.0.backward_conv1d: 15.00%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.0.proj: 15.00%
# 	Sparsity in layers.1.forward_conv1d: 15.00%
# 	Sparsity in layers.1.backward_conv1d: 15.00%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.1.proj: 15.00%
# 	Sparsity in layers.2.forward_conv1d: 15.00%
# 	Sparsity in layers.2.backward_conv1d: 15.00%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.2.proj: 15.00%
# 	Sparsity in layers.3.forward_conv1d: 15.00%
# 	Sparsity in layers.3.backward_conv1d: 15.00%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.3.proj: 15.00%
# 	Sparsity in layers.4.forward_conv1d: 15.00%
# 	Sparsity in layers.4.backward_conv1d: 15.00%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.4.proj: 15.00%
# 	Sparsity in layers.5.forward_conv1d: 15.00%
# 	Sparsity in layers.5.backward_conv1d: 15.00%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.5.proj: 15.00%
# 	Sparsity in layers.6.forward_conv1d: 15.00%
# 	Sparsity in layers.6.backward_conv1d: 15.00%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.6.proj: 15.00%
# 	Sparsity in layers.7.forward_conv1d: 15.00%
# 	Sparsity in layers.7.backward_conv1d: 15.00%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.7.proj: 15.00%
# 	Sparsity in layers.8.forward_conv1d: 15.00%
# 	Sparsity in layers.8.backward_conv1d: 15.00%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.8.proj: 15.00%
# 	Sparsity in layers.9.forward_conv1d: 15.00%
# 	Sparsity in layers.9.backward_conv1d: 15.00%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 15.00%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 14.97%
# 	Sparsity in layers.9.proj: 15.00%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 7.50%
# Epoch 31: Pruned to_patch_embedding.1 to 16.38% sparsity
# Epoch 31: Pruned layers.0.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.0.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.0.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.0.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.0.proj to 16.38% sparsity
# Epoch 31: Pruned layers.1.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.1.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.1.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.1.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.1.proj to 16.38% sparsity
# Epoch 31: Pruned layers.2.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.2.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.2.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.2.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.2.proj to 16.38% sparsity
# Epoch 31: Pruned layers.3.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.3.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.3.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.3.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.3.proj to 16.38% sparsity
# Epoch 31: Pruned layers.4.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.4.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.4.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.4.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.4.proj to 16.38% sparsity
# Epoch 31: Pruned layers.5.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.5.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.5.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.5.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.5.proj to 16.38% sparsity
# Epoch 31: Pruned layers.6.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.6.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.6.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.6.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.6.proj to 16.38% sparsity
# Epoch 31: Pruned layers.7.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.7.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.7.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.7.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.7.proj to 16.38% sparsity
# Epoch 31: Pruned layers.8.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.8.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.8.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.8.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.8.proj to 16.38% sparsity
# Epoch 31: Pruned layers.9.forward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.9.backward_conv1d to 16.38% sparsity
# Epoch 31: Pruned layers.9.ssm.deltaBC_layer to 16.38% sparsity
# Epoch 31: Pruned layers.9.ssm.dt_proj_layer to 16.38% sparsity
# Epoch 31: Pruned layers.9.proj to 16.38% sparsity
# Epoch 31: Pruned output_head.2 to 8.19% sparsity
# Epoch [32/100], Step [1/196], Loss: 0.0037
# Epoch [32/100], Step [101/196], Loss: 0.3814
# Epoch 32 finished. Saving checkpoint...
# After epoch 32:
# 	Sparsity in to_patch_embedding.1: 16.38%
# 	Sparsity in layers.0.forward_conv1d: 16.38%
# 	Sparsity in layers.0.backward_conv1d: 16.38%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.0.proj: 16.38%
# 	Sparsity in layers.1.forward_conv1d: 16.38%
# 	Sparsity in layers.1.backward_conv1d: 16.38%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.1.proj: 16.38%
# 	Sparsity in layers.2.forward_conv1d: 16.38%
# 	Sparsity in layers.2.backward_conv1d: 16.38%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.2.proj: 16.38%
# 	Sparsity in layers.3.forward_conv1d: 16.38%
# 	Sparsity in layers.3.backward_conv1d: 16.38%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.3.proj: 16.38%
# 	Sparsity in layers.4.forward_conv1d: 16.38%
# 	Sparsity in layers.4.backward_conv1d: 16.38%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.4.proj: 16.38%
# 	Sparsity in layers.5.forward_conv1d: 16.38%
# 	Sparsity in layers.5.backward_conv1d: 16.38%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.5.proj: 16.38%
# 	Sparsity in layers.6.forward_conv1d: 16.38%
# 	Sparsity in layers.6.backward_conv1d: 16.38%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.6.proj: 16.38%
# 	Sparsity in layers.7.forward_conv1d: 16.38%
# 	Sparsity in layers.7.backward_conv1d: 16.38%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.7.proj: 16.38%
# 	Sparsity in layers.8.forward_conv1d: 16.38%
# 	Sparsity in layers.8.backward_conv1d: 16.38%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.8.proj: 16.38%
# 	Sparsity in layers.9.forward_conv1d: 16.38%
# 	Sparsity in layers.9.backward_conv1d: 16.38%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 16.38%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 16.41%
# 	Sparsity in layers.9.proj: 16.38%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 8.23%
# Epoch 32: Pruned to_patch_embedding.1 to 17.80% sparsity
# Epoch 32: Pruned layers.0.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.0.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.0.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.0.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.0.proj to 17.80% sparsity
# Epoch 32: Pruned layers.1.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.1.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.1.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.1.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.1.proj to 17.80% sparsity
# Epoch 32: Pruned layers.2.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.2.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.2.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.2.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.2.proj to 17.80% sparsity
# Epoch 32: Pruned layers.3.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.3.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.3.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.3.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.3.proj to 17.80% sparsity
# Epoch 32: Pruned layers.4.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.4.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.4.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.4.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.4.proj to 17.80% sparsity
# Epoch 32: Pruned layers.5.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.5.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.5.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.5.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.5.proj to 17.80% sparsity
# Epoch 32: Pruned layers.6.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.6.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.6.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.6.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.6.proj to 17.80% sparsity
# Epoch 32: Pruned layers.7.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.7.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.7.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.7.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.7.proj to 17.80% sparsity
# Epoch 32: Pruned layers.8.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.8.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.8.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.8.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.8.proj to 17.80% sparsity
# Epoch 32: Pruned layers.9.forward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.9.backward_conv1d to 17.80% sparsity
# Epoch 32: Pruned layers.9.ssm.deltaBC_layer to 17.80% sparsity
# Epoch 32: Pruned layers.9.ssm.dt_proj_layer to 17.80% sparsity
# Epoch 32: Pruned layers.9.proj to 17.80% sparsity
# Epoch 32: Pruned output_head.2 to 8.90% sparsity
# Epoch [33/100], Step [1/196], Loss: 0.0041
# Epoch [33/100], Step [101/196], Loss: 0.3688
# Epoch 33 finished. Saving checkpoint...
# After epoch 33:
# 	Sparsity in to_patch_embedding.1: 17.80%
# 	Sparsity in layers.0.forward_conv1d: 17.80%
# 	Sparsity in layers.0.backward_conv1d: 17.80%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.0.proj: 17.80%
# 	Sparsity in layers.1.forward_conv1d: 17.80%
# 	Sparsity in layers.1.backward_conv1d: 17.80%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.1.proj: 17.80%
# 	Sparsity in layers.2.forward_conv1d: 17.80%
# 	Sparsity in layers.2.backward_conv1d: 17.80%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.2.proj: 17.80%
# 	Sparsity in layers.3.forward_conv1d: 17.80%
# 	Sparsity in layers.3.backward_conv1d: 17.80%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.3.proj: 17.80%
# 	Sparsity in layers.4.forward_conv1d: 17.80%
# 	Sparsity in layers.4.backward_conv1d: 17.80%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.4.proj: 17.80%
# 	Sparsity in layers.5.forward_conv1d: 17.80%
# 	Sparsity in layers.5.backward_conv1d: 17.80%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.5.proj: 17.80%
# 	Sparsity in layers.6.forward_conv1d: 17.80%
# 	Sparsity in layers.6.backward_conv1d: 17.80%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.6.proj: 17.80%
# 	Sparsity in layers.7.forward_conv1d: 17.80%
# 	Sparsity in layers.7.backward_conv1d: 17.80%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.7.proj: 17.80%
# 	Sparsity in layers.8.forward_conv1d: 17.80%
# 	Sparsity in layers.8.backward_conv1d: 17.80%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.8.proj: 17.80%
# 	Sparsity in layers.9.forward_conv1d: 17.80%
# 	Sparsity in layers.9.backward_conv1d: 17.80%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 17.80%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 17.77%
# 	Sparsity in layers.9.proj: 17.80%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 8.85%
# Epoch 33: Pruned to_patch_embedding.1 to 19.25% sparsity
# Epoch 33: Pruned layers.0.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.0.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.0.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.0.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.0.proj to 19.25% sparsity
# Epoch 33: Pruned layers.1.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.1.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.1.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.1.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.1.proj to 19.25% sparsity
# Epoch 33: Pruned layers.2.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.2.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.2.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.2.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.2.proj to 19.25% sparsity
# Epoch 33: Pruned layers.3.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.3.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.3.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.3.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.3.proj to 19.25% sparsity
# Epoch 33: Pruned layers.4.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.4.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.4.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.4.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.4.proj to 19.25% sparsity
# Epoch 33: Pruned layers.5.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.5.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.5.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.5.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.5.proj to 19.25% sparsity
# Epoch 33: Pruned layers.6.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.6.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.6.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.6.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.6.proj to 19.25% sparsity
# Epoch 33: Pruned layers.7.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.7.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.7.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.7.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.7.proj to 19.25% sparsity
# Epoch 33: Pruned layers.8.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.8.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.8.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.8.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.8.proj to 19.25% sparsity
# Epoch 33: Pruned layers.9.forward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.9.backward_conv1d to 19.25% sparsity
# Epoch 33: Pruned layers.9.ssm.deltaBC_layer to 19.25% sparsity
# Epoch 33: Pruned layers.9.ssm.dt_proj_layer to 19.25% sparsity
# Epoch 33: Pruned layers.9.proj to 19.25% sparsity
# Epoch 33: Pruned output_head.2 to 9.62% sparsity
# Epoch [34/100], Step [1/196], Loss: 0.0042
# Epoch [34/100], Step [101/196], Loss: 0.3540
# Epoch 34 finished. Saving checkpoint...
# After epoch 34:
# 	Sparsity in to_patch_embedding.1: 19.25%
# 	Sparsity in layers.0.forward_conv1d: 19.25%
# 	Sparsity in layers.0.backward_conv1d: 19.25%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.0.proj: 19.25%
# 	Sparsity in layers.1.forward_conv1d: 19.25%
# 	Sparsity in layers.1.backward_conv1d: 19.25%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.1.proj: 19.25%
# 	Sparsity in layers.2.forward_conv1d: 19.25%
# 	Sparsity in layers.2.backward_conv1d: 19.25%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.2.proj: 19.25%
# 	Sparsity in layers.3.forward_conv1d: 19.25%
# 	Sparsity in layers.3.backward_conv1d: 19.25%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.3.proj: 19.25%
# 	Sparsity in layers.4.forward_conv1d: 19.25%
# 	Sparsity in layers.4.backward_conv1d: 19.25%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.4.proj: 19.25%
# 	Sparsity in layers.5.forward_conv1d: 19.25%
# 	Sparsity in layers.5.backward_conv1d: 19.25%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.5.proj: 19.25%
# 	Sparsity in layers.6.forward_conv1d: 19.25%
# 	Sparsity in layers.6.backward_conv1d: 19.25%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.6.proj: 19.25%
# 	Sparsity in layers.7.forward_conv1d: 19.25%
# 	Sparsity in layers.7.backward_conv1d: 19.25%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.7.proj: 19.25%
# 	Sparsity in layers.8.forward_conv1d: 19.25%
# 	Sparsity in layers.8.backward_conv1d: 19.25%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.8.proj: 19.25%
# 	Sparsity in layers.9.forward_conv1d: 19.25%
# 	Sparsity in layers.9.backward_conv1d: 19.25%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 19.25%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 19.27%
# 	Sparsity in layers.9.proj: 19.25%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 9.58%
# Epoch 34: Pruned to_patch_embedding.1 to 20.73% sparsity
# Epoch 34: Pruned layers.0.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.0.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.0.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.0.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.0.proj to 20.73% sparsity
# Epoch 34: Pruned layers.1.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.1.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.1.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.1.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.1.proj to 20.73% sparsity
# Epoch 34: Pruned layers.2.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.2.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.2.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.2.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.2.proj to 20.73% sparsity
# Epoch 34: Pruned layers.3.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.3.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.3.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.3.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.3.proj to 20.73% sparsity
# Epoch 34: Pruned layers.4.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.4.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.4.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.4.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.4.proj to 20.73% sparsity
# Epoch 34: Pruned layers.5.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.5.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.5.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.5.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.5.proj to 20.73% sparsity
# Epoch 34: Pruned layers.6.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.6.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.6.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.6.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.6.proj to 20.73% sparsity
# Epoch 34: Pruned layers.7.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.7.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.7.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.7.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.7.proj to 20.73% sparsity
# Epoch 34: Pruned layers.8.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.8.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.8.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.8.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.8.proj to 20.73% sparsity
# Epoch 34: Pruned layers.9.forward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.9.backward_conv1d to 20.73% sparsity
# Epoch 34: Pruned layers.9.ssm.deltaBC_layer to 20.73% sparsity
# Epoch 34: Pruned layers.9.ssm.dt_proj_layer to 20.73% sparsity
# Epoch 34: Pruned layers.9.proj to 20.73% sparsity
# Epoch 34: Pruned output_head.2 to 10.36% sparsity
# Epoch [35/100], Step [1/196], Loss: 0.0032
# Epoch [35/100], Step [101/196], Loss: 0.3223
# Epoch 35 finished. Saving checkpoint...
# After epoch 35:
# 	Sparsity in to_patch_embedding.1: 20.72%
# 	Sparsity in layers.0.forward_conv1d: 20.72%
# 	Sparsity in layers.0.backward_conv1d: 20.72%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.0.proj: 20.72%
# 	Sparsity in layers.1.forward_conv1d: 20.72%
# 	Sparsity in layers.1.backward_conv1d: 20.72%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.1.proj: 20.72%
# 	Sparsity in layers.2.forward_conv1d: 20.72%
# 	Sparsity in layers.2.backward_conv1d: 20.72%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.2.proj: 20.72%
# 	Sparsity in layers.3.forward_conv1d: 20.72%
# 	Sparsity in layers.3.backward_conv1d: 20.72%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.3.proj: 20.72%
# 	Sparsity in layers.4.forward_conv1d: 20.72%
# 	Sparsity in layers.4.backward_conv1d: 20.72%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.4.proj: 20.72%
# 	Sparsity in layers.5.forward_conv1d: 20.72%
# 	Sparsity in layers.5.backward_conv1d: 20.72%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.5.proj: 20.72%
# 	Sparsity in layers.6.forward_conv1d: 20.72%
# 	Sparsity in layers.6.backward_conv1d: 20.72%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.6.proj: 20.72%
# 	Sparsity in layers.7.forward_conv1d: 20.72%
# 	Sparsity in layers.7.backward_conv1d: 20.72%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.7.proj: 20.72%
# 	Sparsity in layers.8.forward_conv1d: 20.72%
# 	Sparsity in layers.8.backward_conv1d: 20.72%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.8.proj: 20.72%
# 	Sparsity in layers.9.forward_conv1d: 20.72%
# 	Sparsity in layers.9.backward_conv1d: 20.72%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 20.73%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 20.70%
# 	Sparsity in layers.9.proj: 20.72%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 10.42%
# Epoch 35: Pruned to_patch_embedding.1 to 22.24% sparsity
# Epoch 35: Pruned layers.0.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.0.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.0.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.0.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.0.proj to 22.24% sparsity
# Epoch 35: Pruned layers.1.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.1.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.1.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.1.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.1.proj to 22.24% sparsity
# Epoch 35: Pruned layers.2.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.2.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.2.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.2.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.2.proj to 22.24% sparsity
# Epoch 35: Pruned layers.3.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.3.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.3.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.3.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.3.proj to 22.24% sparsity
# Epoch 35: Pruned layers.4.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.4.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.4.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.4.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.4.proj to 22.24% sparsity
# Epoch 35: Pruned layers.5.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.5.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.5.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.5.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.5.proj to 22.24% sparsity
# Epoch 35: Pruned layers.6.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.6.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.6.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.6.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.6.proj to 22.24% sparsity
# Epoch 35: Pruned layers.7.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.7.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.7.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.7.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.7.proj to 22.24% sparsity
# Epoch 35: Pruned layers.8.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.8.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.8.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.8.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.8.proj to 22.24% sparsity
# Epoch 35: Pruned layers.9.forward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.9.backward_conv1d to 22.24% sparsity
# Epoch 35: Pruned layers.9.ssm.deltaBC_layer to 22.24% sparsity
# Epoch 35: Pruned layers.9.ssm.dt_proj_layer to 22.24% sparsity
# Epoch 35: Pruned layers.9.proj to 22.24% sparsity
# Epoch 35: Pruned output_head.2 to 11.12% sparsity
# Epoch [36/100], Step [1/196], Loss: 0.0038
# Epoch [36/100], Step [101/196], Loss: 0.3073
# Epoch 36 finished. Saving checkpoint...
# After epoch 36:
# 	Sparsity in to_patch_embedding.1: 22.24%
# 	Sparsity in layers.0.forward_conv1d: 22.23%
# 	Sparsity in layers.0.backward_conv1d: 22.23%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.0.proj: 22.23%
# 	Sparsity in layers.1.forward_conv1d: 22.23%
# 	Sparsity in layers.1.backward_conv1d: 22.23%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.1.proj: 22.23%
# 	Sparsity in layers.2.forward_conv1d: 22.23%
# 	Sparsity in layers.2.backward_conv1d: 22.23%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.2.proj: 22.23%
# 	Sparsity in layers.3.forward_conv1d: 22.23%
# 	Sparsity in layers.3.backward_conv1d: 22.23%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.3.proj: 22.23%
# 	Sparsity in layers.4.forward_conv1d: 22.23%
# 	Sparsity in layers.4.backward_conv1d: 22.23%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.4.proj: 22.23%
# 	Sparsity in layers.5.forward_conv1d: 22.23%
# 	Sparsity in layers.5.backward_conv1d: 22.23%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.5.proj: 22.23%
# 	Sparsity in layers.6.forward_conv1d: 22.23%
# 	Sparsity in layers.6.backward_conv1d: 22.23%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.6.proj: 22.23%
# 	Sparsity in layers.7.forward_conv1d: 22.23%
# 	Sparsity in layers.7.backward_conv1d: 22.23%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.7.proj: 22.23%
# 	Sparsity in layers.8.forward_conv1d: 22.23%
# 	Sparsity in layers.8.backward_conv1d: 22.23%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.8.proj: 22.23%
# 	Sparsity in layers.9.forward_conv1d: 22.23%
# 	Sparsity in layers.9.backward_conv1d: 22.23%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 22.24%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 22.27%
# 	Sparsity in layers.9.proj: 22.23%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 11.15%
# Epoch 36: Pruned to_patch_embedding.1 to 23.76% sparsity
# Epoch 36: Pruned layers.0.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.0.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.0.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.0.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.0.proj to 23.76% sparsity
# Epoch 36: Pruned layers.1.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.1.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.1.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.1.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.1.proj to 23.76% sparsity
# Epoch 36: Pruned layers.2.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.2.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.2.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.2.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.2.proj to 23.76% sparsity
# Epoch 36: Pruned layers.3.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.3.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.3.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.3.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.3.proj to 23.76% sparsity
# Epoch 36: Pruned layers.4.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.4.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.4.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.4.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.4.proj to 23.76% sparsity
# Epoch 36: Pruned layers.5.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.5.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.5.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.5.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.5.proj to 23.76% sparsity
# Epoch 36: Pruned layers.6.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.6.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.6.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.6.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.6.proj to 23.76% sparsity
# Epoch 36: Pruned layers.7.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.7.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.7.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.7.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.7.proj to 23.76% sparsity
# Epoch 36: Pruned layers.8.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.8.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.8.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.8.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.8.proj to 23.76% sparsity
# Epoch 36: Pruned layers.9.forward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.9.backward_conv1d to 23.76% sparsity
# Epoch 36: Pruned layers.9.ssm.deltaBC_layer to 23.76% sparsity
# Epoch 36: Pruned layers.9.ssm.dt_proj_layer to 23.76% sparsity
# Epoch 36: Pruned layers.9.proj to 23.76% sparsity
# Epoch 36: Pruned output_head.2 to 11.88% sparsity
# Epoch [37/100], Step [1/196], Loss: 0.0022
# Epoch [37/100], Step [101/196], Loss: 0.2779
# Epoch 37 finished. Saving checkpoint...
# After epoch 37:
# 	Sparsity in to_patch_embedding.1: 23.76%
# 	Sparsity in layers.0.forward_conv1d: 23.76%
# 	Sparsity in layers.0.backward_conv1d: 23.76%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.0.proj: 23.76%
# 	Sparsity in layers.1.forward_conv1d: 23.76%
# 	Sparsity in layers.1.backward_conv1d: 23.76%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.1.proj: 23.76%
# 	Sparsity in layers.2.forward_conv1d: 23.76%
# 	Sparsity in layers.2.backward_conv1d: 23.76%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.2.proj: 23.76%
# 	Sparsity in layers.3.forward_conv1d: 23.76%
# 	Sparsity in layers.3.backward_conv1d: 23.76%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.3.proj: 23.76%
# 	Sparsity in layers.4.forward_conv1d: 23.76%
# 	Sparsity in layers.4.backward_conv1d: 23.76%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.4.proj: 23.76%
# 	Sparsity in layers.5.forward_conv1d: 23.76%
# 	Sparsity in layers.5.backward_conv1d: 23.76%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.5.proj: 23.76%
# 	Sparsity in layers.6.forward_conv1d: 23.76%
# 	Sparsity in layers.6.backward_conv1d: 23.76%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.6.proj: 23.76%
# 	Sparsity in layers.7.forward_conv1d: 23.76%
# 	Sparsity in layers.7.backward_conv1d: 23.76%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.7.proj: 23.76%
# 	Sparsity in layers.8.forward_conv1d: 23.76%
# 	Sparsity in layers.8.backward_conv1d: 23.76%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.8.proj: 23.76%
# 	Sparsity in layers.9.forward_conv1d: 23.76%
# 	Sparsity in layers.9.backward_conv1d: 23.76%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 23.76%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 23.76%
# 	Sparsity in layers.9.proj: 23.76%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 11.88%
# Epoch 37: Pruned to_patch_embedding.1 to 25.31% sparsity
# Epoch 37: Pruned layers.0.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.0.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.0.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.0.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.0.proj to 25.31% sparsity
# Epoch 37: Pruned layers.1.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.1.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.1.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.1.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.1.proj to 25.31% sparsity
# Epoch 37: Pruned layers.2.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.2.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.2.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.2.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.2.proj to 25.31% sparsity
# Epoch 37: Pruned layers.3.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.3.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.3.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.3.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.3.proj to 25.31% sparsity
# Epoch 37: Pruned layers.4.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.4.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.4.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.4.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.4.proj to 25.31% sparsity
# Epoch 37: Pruned layers.5.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.5.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.5.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.5.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.5.proj to 25.31% sparsity
# Epoch 37: Pruned layers.6.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.6.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.6.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.6.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.6.proj to 25.31% sparsity
# Epoch 37: Pruned layers.7.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.7.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.7.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.7.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.7.proj to 25.31% sparsity
# Epoch 37: Pruned layers.8.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.8.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.8.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.8.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.8.proj to 25.31% sparsity
# Epoch 37: Pruned layers.9.forward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.9.backward_conv1d to 25.31% sparsity
# Epoch 37: Pruned layers.9.ssm.deltaBC_layer to 25.31% sparsity
# Epoch 37: Pruned layers.9.ssm.dt_proj_layer to 25.31% sparsity
# Epoch 37: Pruned layers.9.proj to 25.31% sparsity
# Epoch 37: Pruned output_head.2 to 12.65% sparsity
# Epoch [38/100], Step [1/196], Loss: 0.0040
# Epoch [38/100], Step [101/196], Loss: 0.2700
# Epoch 38 finished. Saving checkpoint...
# After epoch 38:
# 	Sparsity in to_patch_embedding.1: 25.30%
# 	Sparsity in layers.0.forward_conv1d: 25.30%
# 	Sparsity in layers.0.backward_conv1d: 25.30%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.0.proj: 25.30%
# 	Sparsity in layers.1.forward_conv1d: 25.30%
# 	Sparsity in layers.1.backward_conv1d: 25.30%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.1.proj: 25.30%
# 	Sparsity in layers.2.forward_conv1d: 25.30%
# 	Sparsity in layers.2.backward_conv1d: 25.30%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.2.proj: 25.30%
# 	Sparsity in layers.3.forward_conv1d: 25.30%
# 	Sparsity in layers.3.backward_conv1d: 25.30%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.3.proj: 25.30%
# 	Sparsity in layers.4.forward_conv1d: 25.30%
# 	Sparsity in layers.4.backward_conv1d: 25.30%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.4.proj: 25.30%
# 	Sparsity in layers.5.forward_conv1d: 25.30%
# 	Sparsity in layers.5.backward_conv1d: 25.30%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.5.proj: 25.30%
# 	Sparsity in layers.6.forward_conv1d: 25.30%
# 	Sparsity in layers.6.backward_conv1d: 25.30%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 25.33%
# 	Sparsity in layers.6.proj: 25.30%
# 	Sparsity in layers.7.forward_conv1d: 25.30%
# 	Sparsity in layers.7.backward_conv1d: 25.30%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 25.31%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 25.33%
# ...
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 59.84%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 59.83%
# 	Sparsity in layers.8.proj: 59.83%
# 	Sparsity in layers.9.forward_conv1d: 59.83%
# 	Sparsity in layers.9.backward_conv1d: 59.83%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 59.84%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 59.83%
# 	Sparsity in layers.9.proj: 59.83%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 29.90%
# Epoch 69: Pruned to_patch_embedding.1 to 59.96% sparsity
# Epoch 69: Pruned layers.0.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.0.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.0.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.0.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.0.proj to 59.96% sparsity
# Epoch 69: Pruned layers.1.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.1.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.1.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.1.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.1.proj to 59.96% sparsity
# Epoch 69: Pruned layers.2.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.2.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.2.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.2.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.2.proj to 59.96% sparsity
# Epoch 69: Pruned layers.3.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.3.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.3.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.3.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.3.proj to 59.96% sparsity
# Epoch 69: Pruned layers.4.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.4.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.4.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.4.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.4.proj to 59.96% sparsity
# Epoch 69: Pruned layers.5.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.5.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.5.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.5.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.5.proj to 59.96% sparsity
# Epoch 69: Pruned layers.6.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.6.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.6.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.6.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.6.proj to 59.96% sparsity
# Epoch 69: Pruned layers.7.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.7.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.7.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.7.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.7.proj to 59.96% sparsity
# Epoch 69: Pruned layers.8.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.8.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.8.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.8.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.8.proj to 59.96% sparsity
# Epoch 69: Pruned layers.9.forward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.9.backward_conv1d to 59.96% sparsity
# Epoch 69: Pruned layers.9.ssm.deltaBC_layer to 59.96% sparsity
# Epoch 69: Pruned layers.9.ssm.dt_proj_layer to 59.96% sparsity
# Epoch 69: Pruned layers.9.proj to 59.96% sparsity
# Epoch 69: Pruned output_head.2 to 29.98% sparsity
# Epoch [70/100], Step [1/196], Loss: 0.0009
# Epoch [70/100], Step [101/196], Loss: 0.0736
# Epoch 70 finished. Saving checkpoint...
# After epoch 70:
# 	Sparsity in to_patch_embedding.1: 59.96%
# 	Sparsity in layers.0.forward_conv1d: 59.96%
# 	Sparsity in layers.0.backward_conv1d: 59.96%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.0.proj: 59.96%
# 	Sparsity in layers.1.forward_conv1d: 59.96%
# 	Sparsity in layers.1.backward_conv1d: 59.96%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.1.proj: 59.96%
# 	Sparsity in layers.2.forward_conv1d: 59.96%
# 	Sparsity in layers.2.backward_conv1d: 59.96%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.2.proj: 59.96%
# 	Sparsity in layers.3.forward_conv1d: 59.96%
# 	Sparsity in layers.3.backward_conv1d: 59.96%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.3.proj: 59.96%
# 	Sparsity in layers.4.forward_conv1d: 59.96%
# 	Sparsity in layers.4.backward_conv1d: 59.96%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.4.proj: 59.96%
# 	Sparsity in layers.5.forward_conv1d: 59.96%
# 	Sparsity in layers.5.backward_conv1d: 59.96%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.5.proj: 59.96%
# 	Sparsity in layers.6.forward_conv1d: 59.96%
# 	Sparsity in layers.6.backward_conv1d: 59.96%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.6.proj: 59.96%
# 	Sparsity in layers.7.forward_conv1d: 59.96%
# 	Sparsity in layers.7.backward_conv1d: 59.96%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.7.proj: 59.96%
# 	Sparsity in layers.8.forward_conv1d: 59.96%
# 	Sparsity in layers.8.backward_conv1d: 59.96%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.8.proj: 59.96%
# 	Sparsity in layers.9.forward_conv1d: 59.96%
# 	Sparsity in layers.9.backward_conv1d: 59.96%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 59.96%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 59.96%
# 	Sparsity in layers.9.proj: 59.96%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 30.00%
# Epoch 70: Pruned to_patch_embedding.1 to 60.00% sparsity
# Epoch 70: Pruned layers.0.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.0.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.0.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.0.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.0.proj to 60.00% sparsity
# Epoch 70: Pruned layers.1.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.1.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.1.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.1.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.1.proj to 60.00% sparsity
# Epoch 70: Pruned layers.2.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.2.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.2.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.2.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.2.proj to 60.00% sparsity
# Epoch 70: Pruned layers.3.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.3.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.3.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.3.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.3.proj to 60.00% sparsity
# Epoch 70: Pruned layers.4.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.4.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.4.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.4.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.4.proj to 60.00% sparsity
# Epoch 70: Pruned layers.5.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.5.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.5.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.5.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.5.proj to 60.00% sparsity
# Epoch 70: Pruned layers.6.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.6.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.6.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.6.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.6.proj to 60.00% sparsity
# Epoch 70: Pruned layers.7.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.7.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.7.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.7.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.7.proj to 60.00% sparsity
# Epoch 70: Pruned layers.8.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.8.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.8.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.8.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.8.proj to 60.00% sparsity
# Epoch 70: Pruned layers.9.forward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.9.backward_conv1d to 60.00% sparsity
# Epoch 70: Pruned layers.9.ssm.deltaBC_layer to 60.00% sparsity
# Epoch 70: Pruned layers.9.ssm.dt_proj_layer to 60.00% sparsity
# Epoch 70: Pruned layers.9.proj to 60.00% sparsity
# Epoch 70: Pruned output_head.2 to 30.00% sparsity
# Epoch [71/100], Step [1/196], Loss: 0.0006
# Epoch [71/100], Step [101/196], Loss: 0.0619
# Epoch 71 finished. Saving checkpoint...
# After epoch 71:
# 	Sparsity in to_patch_embedding.1: 60.00%
# 	Sparsity in layers.0.forward_conv1d: 60.00%
# 	Sparsity in layers.0.backward_conv1d: 60.00%
# 	Sparsity in layers.0.norm: 0.00%
# 	Sparsity in layers.0.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.0.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.0.proj: 60.00%
# 	Sparsity in layers.1.forward_conv1d: 60.00%
# 	Sparsity in layers.1.backward_conv1d: 60.00%
# 	Sparsity in layers.1.norm: 0.00%
# 	Sparsity in layers.1.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.1.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.1.proj: 60.00%
# 	Sparsity in layers.2.forward_conv1d: 60.00%
# 	Sparsity in layers.2.backward_conv1d: 60.00%
# 	Sparsity in layers.2.norm: 0.00%
# 	Sparsity in layers.2.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.2.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.2.proj: 60.00%
# 	Sparsity in layers.3.forward_conv1d: 60.00%
# 	Sparsity in layers.3.backward_conv1d: 60.00%
# 	Sparsity in layers.3.norm: 0.00%
# 	Sparsity in layers.3.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.3.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.3.proj: 60.00%
# 	Sparsity in layers.4.forward_conv1d: 60.00%
# 	Sparsity in layers.4.backward_conv1d: 60.00%
# 	Sparsity in layers.4.norm: 0.00%
# 	Sparsity in layers.4.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.4.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.4.proj: 60.00%
# 	Sparsity in layers.5.forward_conv1d: 60.00%
# 	Sparsity in layers.5.backward_conv1d: 60.00%
# 	Sparsity in layers.5.norm: 0.00%
# 	Sparsity in layers.5.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.5.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.5.proj: 60.00%
# 	Sparsity in layers.6.forward_conv1d: 60.00%
# 	Sparsity in layers.6.backward_conv1d: 60.00%
# 	Sparsity in layers.6.norm: 0.00%
# 	Sparsity in layers.6.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.6.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.6.proj: 60.00%
# 	Sparsity in layers.7.forward_conv1d: 60.00%
# 	Sparsity in layers.7.backward_conv1d: 60.00%
# 	Sparsity in layers.7.norm: 0.00%
# 	Sparsity in layers.7.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.7.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.7.proj: 60.00%
# 	Sparsity in layers.8.forward_conv1d: 60.00%
# 	Sparsity in layers.8.backward_conv1d: 60.00%
# 	Sparsity in layers.8.norm: 0.00%
# 	Sparsity in layers.8.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.8.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.8.proj: 60.00%
# 	Sparsity in layers.9.forward_conv1d: 60.00%
# 	Sparsity in layers.9.backward_conv1d: 60.00%
# 	Sparsity in layers.9.norm: 0.00%
# 	Sparsity in layers.9.ssm.deltaBC_layer: 60.00%
# 	Sparsity in layers.9.ssm.dt_proj_layer: 60.03%
# 	Sparsity in layers.9.proj: 60.00%
# 	Sparsity in output_head.1: 0.00%
# 	Sparsity in output_head.2: 30.00%
# Epoch [72/100], Step [1/196], Loss: 0.0006
# Epoch [72/100], Step [101/196], Loss: 0.0550
# Epoch 72 finished. Saving checkpoint...
# Epoch [73/100], Step [1/196], Loss: 0.0007
# Epoch [73/100], Step [101/196], Loss: 0.0520
# Epoch 73 finished. Saving checkpoint...
# Epoch [74/100], Step [1/196], Loss: 0.0006
# Epoch [74/100], Step [101/196], Loss: 0.0490
# Epoch 74 finished. Saving checkpoint...
# Epoch [75/100], Step [1/196], Loss: 0.0005
# Epoch [75/100], Step [101/196], Loss: 0.0461
# Epoch 75 finished. Saving checkpoint...
# Epoch [76/100], Step [1/196], Loss: 0.0004
# Epoch [76/100], Step [101/196], Loss: 0.0440
# Epoch 76 finished. Saving checkpoint...
# Epoch [77/100], Step [1/196], Loss: 0.0005
# Epoch [77/100], Step [101/196], Loss: 0.0398
# Epoch 77 finished. Saving checkpoint...
# Epoch [78/100], Step [1/196], Loss: 0.0005
# Epoch [78/100], Step [101/196], Loss: 0.0392
# Epoch 78 finished. Saving checkpoint...
# Epoch [79/100], Step [1/196], Loss: 0.0004
# Epoch [79/100], Step [101/196], Loss: 0.0362
# Epoch 79 finished. Saving checkpoint...
# Epoch [80/100], Step [1/196], Loss: 0.0005
# Epoch [80/100], Step [101/196], Loss: 0.0346
# Epoch 80 finished. Saving checkpoint...
# Epoch [81/100], Step [1/196], Loss: 0.0004
# Epoch [81/100], Step [101/196], Loss: 0.0324
# Epoch 81 finished. Saving checkpoint...
# Epoch [82/100], Step [1/196], Loss: 0.0003
# Epoch [82/100], Step [101/196], Loss: 0.0308
# Epoch 82 finished. Saving checkpoint...
# Epoch [83/100], Step [1/196], Loss: 0.0002
# Epoch [83/100], Step [101/196], Loss: 0.0285
# Epoch 83 finished. Saving checkpoint...
# Epoch [84/100], Step [1/196], Loss: 0.0006
# Epoch [84/100], Step [101/196], Loss: 0.0255
# Epoch 84 finished. Saving checkpoint...
# Epoch [85/100], Step [1/196], Loss: 0.0003
# Epoch [85/100], Step [101/196], Loss: 0.0274
# Epoch 85 finished. Saving checkpoint...
# Epoch [86/100], Step [1/196], Loss: 0.0005
# Epoch [86/100], Step [101/196], Loss: 0.0259
# Epoch 86 finished. Saving checkpoint...
# Epoch [87/100], Step [1/196], Loss: 0.0002
# Epoch [87/100], Step [101/196], Loss: 0.0248
# Epoch 87 finished. Saving checkpoint...
# Epoch [88/100], Step [1/196], Loss: 0.0002
# Epoch [88/100], Step [101/196], Loss: 0.0243
# Epoch 88 finished. Saving checkpoint...
# Epoch [89/100], Step [1/196], Loss: 0.0002
# Epoch [89/100], Step [101/196], Loss: 0.0231
# Epoch 89 finished. Saving checkpoint...
# Epoch [90/100], Step [1/196], Loss: 0.0002
# Epoch [90/100], Step [101/196], Loss: 0.0239
# Epoch 90 finished. Saving checkpoint...
# Epoch [91/100], Step [1/196], Loss: 0.0002
# Epoch [91/100], Step [101/196], Loss: 0.0222
# Epoch 91 finished. Saving checkpoint...
# Epoch [92/100], Step [1/196], Loss: 0.0002
# Epoch [92/100], Step [101/196], Loss: 0.0212
# Epoch 92 finished. Saving checkpoint...
# Epoch [93/100], Step [1/196], Loss: 0.0003
# Epoch [93/100], Step [101/196], Loss: 0.0222
# Epoch 93 finished. Saving checkpoint...
# Epoch [94/100], Step [1/196], Loss: 0.0003
# Epoch [94/100], Step [101/196], Loss: 0.0219
# Epoch 94 finished. Saving checkpoint...
# Epoch [95/100], Step [1/196], Loss: 0.0003
# Epoch [95/100], Step [101/196], Loss: 0.0224
# Epoch 95 finished. Saving checkpoint...
# Epoch [96/100], Step [1/196], Loss: 0.0002
# Epoch [96/100], Step [101/196], Loss: 0.0213
# Epoch 96 finished. Saving checkpoint...
# Epoch [97/100], Step [1/196], Loss: 0.0002
# Epoch [97/100], Step [101/196], Loss: 0.0206
# Epoch 97 finished. Saving checkpoint...
# Epoch [98/100], Step [1/196], Loss: 0.0002
# Epoch [98/100], Step [101/196], Loss: 0.0211
# Epoch 98 finished. Saving checkpoint...
# Epoch [99/100], Step [1/196], Loss: 0.0002
# Epoch [99/100], Step [101/196], Loss: 0.0215
# Epoch 99 finished. Saving checkpoint...
# Epoch [100/100], Step [1/196], Loss: 0.0002
# Epoch [100/100], Step [101/196], Loss: 0.0209
# Epoch 100 finished. Saving checkpoint...

# %%
torch.save(model.state_dict(), os.path.join(CHECKPOINT_PATH, f'final_checkpoint_with_masks.pt'))

for name, module in model.named_modules():
    if hasattr(module, "weight_mask") and (isinstance(module, nn.Conv1d) or isinstance(module, nn.Linear)):
        prune.remove(module, "weight")
        print(f"Removed pruning mask from {name}")

torch.save(model.state_dict(), os.path.join(CHECKPOINT_PATH, f'final_checkpoint.pt'))
# Out:
# Removed pruning mask from to_patch_embedding.1
# Removed pruning mask from layers.0.forward_conv1d
# Removed pruning mask from layers.0.backward_conv1d
# Removed pruning mask from layers.0.ssm.deltaBC_layer
# Removed pruning mask from layers.0.ssm.dt_proj_layer
# Removed pruning mask from layers.0.proj
# Removed pruning mask from layers.1.forward_conv1d
# Removed pruning mask from layers.1.backward_conv1d
# Removed pruning mask from layers.1.ssm.deltaBC_layer
# Removed pruning mask from layers.1.ssm.dt_proj_layer
# Removed pruning mask from layers.1.proj
# Removed pruning mask from layers.2.forward_conv1d
# Removed pruning mask from layers.2.backward_conv1d
# Removed pruning mask from layers.2.ssm.deltaBC_layer
# Removed pruning mask from layers.2.ssm.dt_proj_layer
# Removed pruning mask from layers.2.proj
# Removed pruning mask from layers.3.forward_conv1d
# Removed pruning mask from layers.3.backward_conv1d
# Removed pruning mask from layers.3.ssm.deltaBC_layer
# Removed pruning mask from layers.3.ssm.dt_proj_layer
# Removed pruning mask from layers.3.proj
# Removed pruning mask from layers.4.forward_conv1d
# Removed pruning mask from layers.4.backward_conv1d
# Removed pruning mask from layers.4.ssm.deltaBC_layer
# Removed pruning mask from layers.4.ssm.dt_proj_layer
# Removed pruning mask from layers.4.proj
# Removed pruning mask from layers.5.forward_conv1d
# Removed pruning mask from layers.5.backward_conv1d
# Removed pruning mask from layers.5.ssm.deltaBC_layer
# Removed pruning mask from layers.5.ssm.dt_proj_layer
# Removed pruning mask from layers.5.proj
# Removed pruning mask from layers.6.forward_conv1d
# Removed pruning mask from layers.6.backward_conv1d
# Removed pruning mask from layers.6.ssm.deltaBC_layer
# Removed pruning mask from layers.6.ssm.dt_proj_layer
# Removed pruning mask from layers.6.proj
# Removed pruning mask from layers.7.forward_conv1d
# Removed pruning mask from layers.7.backward_conv1d
# Removed pruning mask from layers.7.ssm.deltaBC_layer
# Removed pruning mask from layers.7.ssm.dt_proj_layer
# Removed pruning mask from layers.7.proj
# Removed pruning mask from layers.8.forward_conv1d
# Removed pruning mask from layers.8.backward_conv1d
# Removed pruning mask from layers.8.ssm.deltaBC_layer
# Removed pruning mask from layers.8.ssm.dt_proj_layer
# Removed pruning mask from layers.8.proj
# Removed pruning mask from layers.9.forward_conv1d
# Removed pruning mask from layers.9.backward_conv1d
# Removed pruning mask from layers.9.ssm.deltaBC_layer
# Removed pruning mask from layers.9.ssm.dt_proj_layer
# Removed pruning mask from layers.9.proj
# Removed pruning mask from output_head.2

# %%
_end = time.time()
print(_end)

with open(os.path.join(CHECKPOINT_PATH, 'trainning_time.txt'), 'w') as f:
  f.write(f"Start Time: {_start}\nEnd Time:{_end}\nTotal Time:{_end - _start}")


DF = pd.DataFrame(np.array(__losses))
DF.to_csv(os.path.join(CHECKPOINT_PATH, 'losses.csv'))
# Out:
# 1731910072.9769154

# %%
from torchinfo import summary
summary(model, input_size=(batch_size, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Vim                                      [256, 10]                 96
# ├─Sequential: 1-1                        [256, 64, 96]             --
# │    └─Rearrange: 2-1                    [256, 64, 48]             --
# │    └─Linear: 2-2                       [256, 64, 96]             4,704
# ├─Dropout: 1-2                           [256, 64, 96]             --
# ├─ModuleList: 1-3                        --                        --
# │    └─VisionEncoderMambaBlock: 2-3      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-1               [256, 64, 96]             192
# │    │    └─Linear: 3-2                  [256, 64, 96]             9,312
# │    │    └─SiLU: 3-3                    [256, 64, 96]             --
# │    │    └─Linear: 3-4                  [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-5                  [256, 96, 64]             9,312
# │    │    └─Softplus: 3-6                [256, 96, 64]             --
# │    │    └─SSM: 3-7                     [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-8                  [256, 96, 64]             9,312
# │    │    └─Softplus: 3-9                [256, 96, 64]             --
# │    │    └─SSM: 3-10                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-4      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-11              [256, 64, 96]             192
# │    │    └─Linear: 3-12                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-13                   [256, 64, 96]             --
# │    │    └─Linear: 3-14                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-15                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-16               [256, 96, 64]             --
# │    │    └─SSM: 3-17                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-18                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-19               [256, 96, 64]             --
# │    │    └─SSM: 3-20                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-5      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-21              [256, 64, 96]             192
# │    │    └─Linear: 3-22                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-23                   [256, 64, 96]             --
# │    │    └─Linear: 3-24                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-25                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-26               [256, 96, 64]             --
# │    │    └─SSM: 3-27                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-28                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-29               [256, 96, 64]             --
# │    │    └─SSM: 3-30                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-6      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-31              [256, 64, 96]             192
# │    │    └─Linear: 3-32                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-33                   [256, 64, 96]             --
# │    │    └─Linear: 3-34                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-35                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-36               [256, 96, 64]             --
# │    │    └─SSM: 3-37                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-38                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-39               [256, 96, 64]             --
# │    │    └─SSM: 3-40                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-7      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-41              [256, 64, 96]             192
# │    │    └─Linear: 3-42                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-43                   [256, 64, 96]             --
# │    │    └─Linear: 3-44                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-45                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-46               [256, 96, 64]             --
# │    │    └─SSM: 3-47                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-48                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-49               [256, 96, 64]             --
# │    │    └─SSM: 3-50                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-8      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-51              [256, 64, 96]             192
# │    │    └─Linear: 3-52                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-53                   [256, 64, 96]             --
# │    │    └─Linear: 3-54                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-55                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-56               [256, 96, 64]             --
# │    │    └─SSM: 3-57                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-58                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-59               [256, 96, 64]             --
# │    │    └─SSM: 3-60                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-9      [256, 64, 96]             --
# │    │    └─LayerNorm: 3-61              [256, 64, 96]             192
# │    │    └─Linear: 3-62                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-63                   [256, 64, 96]             --
# │    │    └─Linear: 3-64                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-65                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-66               [256, 96, 64]             --
# │    │    └─SSM: 3-67                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-68                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-69               [256, 96, 64]             --
# │    │    └─SSM: 3-70                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-10     [256, 64, 96]             --
# │    │    └─LayerNorm: 3-71              [256, 64, 96]             192
# │    │    └─Linear: 3-72                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-73                   [256, 64, 96]             --
# │    │    └─Linear: 3-74                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-75                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-76               [256, 96, 64]             --
# │    │    └─SSM: 3-77                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-78                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-79               [256, 96, 64]             --
# │    │    └─SSM: 3-80                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-11     [256, 64, 96]             --
# │    │    └─LayerNorm: 3-81              [256, 64, 96]             192
# │    │    └─Linear: 3-82                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-83                   [256, 64, 96]             --
# │    │    └─Linear: 3-84                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-85                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-86               [256, 96, 64]             --
# │    │    └─SSM: 3-87                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-88                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-89               [256, 96, 64]             --
# │    │    └─SSM: 3-90                    [256, 64, 96]             (recursive)
# │    └─VisionEncoderMambaBlock: 2-12     [256, 64, 96]             --
# │    │    └─LayerNorm: 3-91              [256, 64, 96]             192
# │    │    └─Linear: 3-92                 [256, 64, 96]             9,312
# │    │    └─SiLU: 3-93                   [256, 64, 96]             --
# │    │    └─Linear: 3-94                 [256, 64, 96]             (recursive)
# │    │    └─Conv1d: 3-95                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-96               [256, 96, 64]             --
# │    │    └─SSM: 3-97                    [256, 64, 96]             30,912
# │    │    └─Conv1d: 3-98                 [256, 96, 64]             9,312
# │    │    └─Softplus: 3-99               [256, 96, 64]             --
# │    │    └─SSM: 3-100                   [256, 64, 96]             (recursive)
# ├─Identity: 1-4                          [256, 64, 96]             --
# ├─Sequential: 1-5                        [256, 10]                 --
# │    └─Reduce: 2-13                      [256, 96]                 --
# │    └─LayerNorm: 2-14                   [256, 96]                 192
# │    └─Linear: 2-15                      [256, 10]                 970
# ==========================================================================================
# Total params: 596,362
# Trainable params: 596,362
# Non-trainable params: 0
# Total mult-adds (G): 3.21
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 1438.86
# Params size (MB): 2.01
# Estimated Total Size (MB): 1444.02
# ==========================================================================================

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for inputs,labels in testing_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f"accuracy of the model test images: {(100 * correct / total):.2f}%")
# Out:
# accuracy of the model test images: 70.02%

# %%
print(torch.cuda.memory_summary(device=None, abbreviated=False))
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  29278 KiB |  38768 MiB |   5439 TiB |   5439 TiB |
# |       from large pool |  19712 KiB |  38753 MiB |   5438 TiB |   5438 TiB |
# |       from small pool |   9566 KiB |     17 MiB |      1 TiB |      1 TiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  29278 KiB |  38768 MiB |   5439 TiB |   5439 TiB |
# |       from large pool |  19712 KiB |  38753 MiB |   5438 TiB |   5438 TiB |
# |       from small pool |   9566 KiB |     17 MiB |      1 TiB |      1 TiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |  29236 KiB |  38764 MiB |   5438 TiB |   5438 TiB |
# |       from large pool |  19712 KiB |  38749 MiB |   5437 TiB |   5437 TiB |
# |       from small pool |   9524 KiB |     17 MiB |      1 TiB |      1 TiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  39294 MiB |  39294 MiB |  39294 MiB |      0 B   |
# |       from large pool |  39274 MiB |  39274 MiB |  39274 MiB |      0 B   |
# |       from small pool |     20 MiB |     20 MiB |     20 MiB |      0 B   |
# |---------------------------------------------------------------------------|
# | Non-releasable memory | 302497 KiB |   1831 MiB | 628220 GiB | 628220 GiB |
# |       from large pool | 295680 KiB |   1828 MiB | 627095 GiB | 627095 GiB |
# |       from small pool |   6817 KiB |      9 MiB |   1124 GiB |   1124 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     558    |     878    |   46887 K  |   46886 K  |
# |       from large pool |       3    |     263    |   32340 K  |   32340 K  |
# |       from small pool |     555    |     792    |   14546 K  |   14546 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |     558    |     878    |   46887 K  |   46886 K  |
# |       from large pool |       3    |     263    |   32340 K  |   32340 K  |
# |       from small pool |     555    |     792    |   14546 K  |   14546 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      87    |      87    |      87    |       0    |
# |       from large pool |      77    |      77    |      77    |       0    |
# |       from small pool |      10    |      10    |      10    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      80    |      98    |   18278 K  |   18278 K  |
# |       from large pool |       3    |      31    |   10280 K  |   10280 K  |
# |       from small pool |      77    |      95    |    7998 K  |    7997 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
